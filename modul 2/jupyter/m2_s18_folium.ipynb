# %% [markdown]
# # **Introduction to Folium**
#
# Kita akan belajar cara membuat peta untuk berbagai tujuan. Untuk melakukannya, kita akan berpisah dengan Matplotlib dan bekerja dengan pustaka visualisasi Python lainnya, yaitu **Folium**. Hal yang menarik tentang **Folium** adalah ia dikembangkan hanya untuk tujuan memvisualisasikan data geospasial.
#
# Meskipun pustaka lain tersedia untuk memvisualisasikan data geospasial, seperti **plotly**, pustaka tersebut mungkin memiliki batasan terkait berapa banyak panggilan API yang dapat dilakukan dalam jangka waktu yang ditentukan. Sedangkan **Folium** sepenuhnya gratis.
# ___

# %%
# data manipulation
import numpy as np
import pandas as pd

# visualization
import folium

# %% [markdown]
# ## **1. What is Folium?**
#
#
# Folium adalah sebuah library Python yang powerful yang membantu Anda membuat berbagai jenis peta Leaflet. Fakta bahwa hasil dari Folium interaktif membuat library ini sangat berguna untuk membangun dashboard.
#
# Dari halaman dokumentasi resmi Folium:
#
# > Folium memanfaatkan kekuatan pengolahan data dari ekosistem Python dan kekuatan pemetaan dari pustaka Leaflet.js. Manipulasi data Anda di Python, kemudian visualisasikan pada peta Leaflet melalui Folium.
#
# > Folium memudahkan untuk memvisualisasikan data yang telah dimanipulasi di Python pada peta Leaflet interaktif. Ini memungkinkan pengikatan data ke peta untuk visualisasi choropleth serta melewati visualisasi Vincent/Vega sebagai penanda pada peta.
#
# > Pustaka ini memiliki sejumlah tilesets bawaan dari OpenStreetMap, Mapbox, Cartodb, dan mendukung tilesets kustom dengan kunci API Mapbox atau Cloudmade. Folium mendukung baik overlay GeoJSON maupun TopoJSON, serta pengikatan data ke overlay tersebut untuk membuat peta choropleth dengan skema warna color-brewer.

# %% [markdown]
# ## **2. Generating Maps**
#
#
# Membuat peta dunia sangat mudah di Folium. Kita hanya perlu membuat objek `Map` Folium, dan kemudian menampilkannya. Yang menarik dari peta Folium adalah bahwa mereka interaktif, sehingga kita dapat memperbesar tampilan ke area mana pun yang menarik meskipun pada tingkat zoom awal.

# %%
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9922bc820d3c55d5ff13b7da2bf0dd43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9922bc820d3c55d5ff13b7da2bf0dd43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9922bc820d3c55d5ff13b7da2bf0dd43 = L.map(
#                 &quot;map_9922bc820d3c55d5ff13b7da2bf0dd43&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf7d74a2c04a9d32a391553c78f97b5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bf7d74a2c04a9d32a391553c78f97b5a.addTo(map_9922bc820d3c55d5ff13b7da2bf0dd43);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Coba perbesar dan perkecil peta yang diberikan di atas.
#
# Kita dapat menyesuaikan definisi default peta dunia ini dengan menentukan pusat peta kita, dan tingkat zoom awal.
#
# Semua lokasi pada peta didefinisikan oleh nilai Latitude dan Longitude mereka masing-masing. Jadi kita dapat membuat peta dan menyertakan pusat nilai Latitude dan Longitude **[0, 0]**.
#
# Untuk pusat yang ditentukan, kita juga dapat menentukan tingkat zoom awal ke lokasi tersebut saat peta dirender. **Semakin tinggi tingkat zoom, semakin besar peta diperbesar ke pusatnya.**
#
# Mari kita membuat peta yang berpusat di sekitar Jakarta dan bermain dengan tingkat zoom untuk melihat bagaimana itu memengaruhi peta yang dirender.

# %%
# menampilkan peta jakarta yang terpusat di monas
lat_monas = -6.175392
long_monas = 106.827153

jakarta_map=folium.Map(
    [lat_monas, long_monas],                 # latitude, longitude
    zoom_start=12                            # ukuran zoom awal
)

jakarta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ca3c2d4f3985ee587efc61ec572cfbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ca3c2d4f3985ee587efc61ec572cfbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ca3c2d4f3985ee587efc61ec572cfbf = L.map(
#                 &quot;map_8ca3c2d4f3985ee587efc61ec572cfbf&quot;,
#                 {
#                     center: [-6.175392, 106.827153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64c4f53c69d2055083efda3ebb8ff99d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_64c4f53c69d2055083efda3ebb8ff99d.addTo(map_8ca3c2d4f3985ee587efc61ec572cfbf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Seperti yang kita lihat, semakin tinggi tingkat zoom, semakin besar peta diperbesar ke bagian tengahnya.

# %% [markdown]
# ## **2. Map Style**
#
# Fitur keren lainnya dari **Folium** adalah kita dapat menghasilkan gaya peta yang berbeda.
#
# ### `Cartodb dark_matter Maps`
#
# Ini adalah peta hitam putih dengan kontras tinggi. Cocok untuk penggabungan data dan menjelajahi liku-liku sungai dan zona pesisir.
#
# Mari kita membuat peta Cartodb dark_matter Surabaya dengan tingkat zoom 12.

# %%
# membuat peta surabaya
surabaya_map = folium.Map(
    [-7.250445, 112.768845],
    zoom_start=12,
    tiles='Cartodb dark_matter'         # style pada peta (by default open street map)
)

surabaya_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_daf363169eec3f4ca1fa907ce80855ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_daf363169eec3f4ca1fa907ce80855ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_daf363169eec3f4ca1fa907ce80855ed = L.map(
#                 &quot;map_daf363169eec3f4ca1fa907ce80855ed&quot;,
#                 {
#                     center: [-7.250445, 112.768845],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d68282a3aef86e569fea52f225c2727 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2d68282a3aef86e569fea52f225c2727.addTo(map_daf363169eec3f4ca1fa907ce80855ed);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### `Cartodb positron Maps`
#
# Peta CartoDB Positron didesain dengan estetika ringan dan minimalis. Mereka memiliki latar belakang putih atau berwarna terang dan menampilkan garis-garis sederhana dan bersih untuk elemen peta. Peta-peta ini dikenal dengan desainnya yang modern dan menarik secara visual.
#
# Mari kita membuat peta Cartodb Positron Bandung dengan tingkat zoom 12.

# %%
# membuat peta bandung
bandung_map = folium.Map(
    [-6.905977, 107.613144],
    zoom_start=12,
    tiles='Cartodb positron'         # style pada peta (by default open street map)
)

bandung_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b1aa4a58bd35ea047f1c1fa236d6119 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b1aa4a58bd35ea047f1c1fa236d6119&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b1aa4a58bd35ea047f1c1fa236d6119 = L.map(
#                 &quot;map_6b1aa4a58bd35ea047f1c1fa236d6119&quot;,
#                 {
#                     center: [-6.905977, 107.613144],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1d72cd94bc0c988be69e8cff7590285 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a1d72cd94bc0c988be69e8cff7590285.addTo(map_6b1aa4a58bd35ea047f1c1fa236d6119);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Add custom base maps to folium
basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# %%
# membuat peta bandung
bandung_map = folium.Map(
    [-6.905977, 107.613144],
    zoom_start=12,
    tiles='Cartodb positron'         # style pada peta (by default open street map)
)

basemaps['Esri Satellite'].add_to(bandung_map)
bandung_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61cff0c0a4f1a3895608512e3fdb6229 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61cff0c0a4f1a3895608512e3fdb6229&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61cff0c0a4f1a3895608512e3fdb6229 = L.map(
#                 &quot;map_61cff0c0a4f1a3895608512e3fdb6229&quot;,
#                 {
#                     center: [-6.905977, 107.613144],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c216a4ecac9da539571987783e59def9 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c216a4ecac9da539571987783e59def9.addTo(map_61cff0c0a4f1a3895608512e3fdb6229);
#
#
#             var tile_layer_a744dd0cd1c5d3536f4a5b68582be9f4 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a744dd0cd1c5d3536f4a5b68582be9f4.addTo(map_61cff0c0a4f1a3895608512e3fdb6229);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## **3. Maps with Markers**
#
# Kita dapat menambahkan penanda pada suatu peta. Kita dapat menambahkan penanda ini ke peta kita dengan memanggil `folium.Marker()` dan menyimpan lokasi titik tersebut

# %%
# menampilkan peta jakarta yang terpusat di monas
lat_monas = -6.175392
long_monas = 106.827153

jakarta_map=folium.Map(
    [lat_monas, long_monas],                 # latitude, longitude
    zoom_start=12                            # ukuran zoom awal
)

# membuat marker monas
monas_pin = folium.Marker(
    location=[lat_monas, long_monas],                                   # titik koordinat dari monas
    tooltip='Monumen Nasional',                                         # menambahkan tooltip saat dihover
    popup='Monas merupakan monumen peringatan setinggi 132 meter',      # menambahkan popup saat diklik
    icon=folium.Icon(
        icon='building',
        prefix='fa',                                                    # memberitahu icon dari font awesome
        color='red'
    )
)

# membuat marker halim
halim_pin = folium.Marker(
    location=[-6.265135263345276, 106.88561716891712],                  # titik koordinat dari halim
    tooltip='Halim Perdana Kusuma',                                     # menambahkan tooltip saat dihover
    popup='Bandar udara sipil utama di kota Jakarta',                    # menambahkan popup saat diklik
    icon=folium.Icon(
        icon='plane',
        prefix='fa',                                                    # memberitahu icon dari font awesome
        color='orange'
    )
)

# membuat marker berupa lingkaran
pik_area = folium.CircleMarker(                                    # ukuran lingkaran tidak akan berubah saat di zoom in/zoom out
    location=[-6.108895599868524, 106.73998549590095],
    tooltip='Pantai Indah Kapuk',
    popup='Kawasatan wisata di area utara Jakarta',
    radius=100,                                                    # radius dalam pixel
    color='green'
)

# membuat marker berupa lingkaran
kotatua_area = folium.Circle(                                      # ukuran lingkaran akan berubah saat di zoom in/zoom out
    location=[-6.134620574161364, 106.8295444904468],
    tooltip='Kota Tua',
    popup='Kawasatan banjir',
    radius=1000,                                                   # radius dalam meter
    color='red'
)

monas_pin.add_to(jakarta_map)
halim_pin.add_to(jakarta_map)
pik_area.add_to(jakarta_map)
kotatua_area.add_to(jakarta_map)

jakarta_map

# pilihan warna: 'red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen'
# 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray'
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4b8f71a9b65f61f255ee2fd77f446f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4b8f71a9b65f61f255ee2fd77f446f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4b8f71a9b65f61f255ee2fd77f446f4 = L.map(
#                 &quot;map_b4b8f71a9b65f61f255ee2fd77f446f4&quot;,
#                 {
#                     center: [-6.175392, 106.827153],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20c34cb67e8ff4a2da44494c2f9986cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_20c34cb67e8ff4a2da44494c2f9986cb.addTo(map_b4b8f71a9b65f61f255ee2fd77f446f4);
#
#
#             var marker_0712ff2e58d85a3c72a64bda7a20da77 = L.marker(
#                 [-6.175392, 106.827153],
#                 {}
#             ).addTo(map_b4b8f71a9b65f61f255ee2fd77f446f4);
#
#
#             var icon_e6fbc6d3019c4bd3673e641d04f758a9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0712ff2e58d85a3c72a64bda7a20da77.setIcon(icon_e6fbc6d3019c4bd3673e641d04f758a9);
#
#
#         var popup_52277f0ed29cc1e1534605fed4778b02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41000ffc493f4ba941d2ee13adc7f68d = $(`&lt;div id=&quot;html_41000ffc493f4ba941d2ee13adc7f68d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Monas merupakan monumen peringatan setinggi 132 meter&lt;/div&gt;`)[0];
#                 popup_52277f0ed29cc1e1534605fed4778b02.setContent(html_41000ffc493f4ba941d2ee13adc7f68d);
#
#
#
#         marker_0712ff2e58d85a3c72a64bda7a20da77.bindPopup(popup_52277f0ed29cc1e1534605fed4778b02)
#         ;
#
#
#
#
#             marker_0712ff2e58d85a3c72a64bda7a20da77.bindTooltip(
#                 `&lt;div&gt;
#                      Monumen Nasional
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0cd40a2d2a3c4d23a25c55c798922524 = L.marker(
#                 [-6.265135263345276, 106.88561716891712],
#                 {}
#             ).addTo(map_b4b8f71a9b65f61f255ee2fd77f446f4);
#
#
#             var icon_baab85dbe5d6bd9f86746defa757820e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0cd40a2d2a3c4d23a25c55c798922524.setIcon(icon_baab85dbe5d6bd9f86746defa757820e);
#
#
#         var popup_966fca436a620f162b3cd04b5a0a865e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b157b606d3e7dcd0514675c99c716b98 = $(`&lt;div id=&quot;html_b157b606d3e7dcd0514675c99c716b98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bandar udara sipil utama di kota Jakarta&lt;/div&gt;`)[0];
#                 popup_966fca436a620f162b3cd04b5a0a865e.setContent(html_b157b606d3e7dcd0514675c99c716b98);
#
#
#
#         marker_0cd40a2d2a3c4d23a25c55c798922524.bindPopup(popup_966fca436a620f162b3cd04b5a0a865e)
#         ;
#
#
#
#
#             marker_0cd40a2d2a3c4d23a25c55c798922524.bindTooltip(
#                 `&lt;div&gt;
#                      Halim Perdana Kusuma
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_42c7af485a71f24f67fdbf4a8ade9846 = L.circleMarker(
#                 [-6.108895599868524, 106.73998549590095],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b4b8f71a9b65f61f255ee2fd77f446f4);
#
#
#         var popup_885c9d9ee268e2ca751818de2e8a0b0b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a20ca438007a5747aafa271280ebda6 = $(`&lt;div id=&quot;html_2a20ca438007a5747aafa271280ebda6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kawasatan wisata di area utara Jakarta&lt;/div&gt;`)[0];
#                 popup_885c9d9ee268e2ca751818de2e8a0b0b.setContent(html_2a20ca438

# %% [markdown]
# Selanjutnya kita akan coba membuat marker dengan data yang lain. Mari unduh dan impor data insiden departemen kepolisian menggunakan metode *pandas* `read_csv()`. Unduh dataset dan simpan dalam dataframe *pandas*:

# %%
df_incidents = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Police_Department_Incidents_-_Previous_Year__2016_.csv')
df_incidents.head()
# Out:
#    IncidntNum      Category                                        Descript  \
# 0   120058272   WEAPON LAWS                       POSS OF PROHIBITED WEAPON
# 1   120058272   WEAPON LAWS  FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE
# 2   141059263      WARRANTS                                  WARRANT ARREST
# 3   160013662  NON-CRIMINAL                                   LOST PROPERTY
# 4   160002740  NON-CRIMINAL                                   LOST PROPERTY
#
#   DayOfWeek                    Date   Time  PdDistrict      Resolution  \
# 0    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 1    Friday  01/29/2016 12:00:00 AM  11:00    SOUTHERN  ARREST, BOOKED
# 2    Monday  04/25/2016 12:00:00 AM  14:59     BAYVIEW  ARREST, BOOKED
# 3   Tuesday  01/05/2016 12:00:00 AM  23:50  TENDERLOIN            NONE
# 4    Friday  01/01/2016 12:00:00 AM  00:30     MISSION            NONE
#
#                   Address           X          Y  \
# 0  800 Block of BRYANT ST -122.403405  37.775421
# 1  800 Block of BRYANT ST -122.403405  37.775421
# 2   KEITH ST / SHAFTER AV -122.388856  37.729981
# 3  JONES ST / OFARRELL ST -122.412971  37.785788
# 4    16TH ST / MISSION ST -122.419672  37.765050
#
#                                 Location            PdId
# 0   (37.775420706711, -122.403404791479)  12005827212120
# 1   (37.775420706711, -122.403404791479)  12005827212168
# 2  (37.7299809672996, -122.388856204292)  14105926363010
# 3  (37.7857883766888, -122.412970537591)  16001366271000
# 4  (37.7650501214668, -122.419671780296)  16000274071000

# %% [markdown]
# Setiap baris terdiri dari 13 fitur:
# > 1. **IncidntNum**: Incident Number
# > 2. **Category**: Category of crime or incident
# > 3. **Descript**: Description of the crime or incident
# > 4. **DayOfWeek**: The day of week on which the incident occurred
# > 5. **Date**: The Date on which the incident occurred
# > 6. **Time**: The time of day on which the incident occurred
# > 7. **PdDistrict**: The police department district
# > 8. **Resolution**: The resolution of the crime in terms whether the perpetrator was arrested or not
# > 9. **Address**: The closest address to where the incident took place
# > 10. **X**: The longitude value of the crime location
# > 11. **Y**: The latitude value of the crime location
# > 12. **Location**: A tuple of the latitude and the longitude values
# > 13. **PdId**: The police department ID

# %% [markdown]
# Mari kita cari tahu berapa banyak entri yang ada di dataset kita.

# %%
df_incidents.shape
# Out:
# (150500, 13)

# %% [markdown]
# Jadi datframenya terdiri dari 150.500 kejahatan yang terjadi pada tahun 2016. Untuk mengurangi biaya komputasi, mari kita kerjakan 100 insiden pertama dalam kumpulan data ini.

# %%
df_incidents = df_incidents.head(100)

# %% [markdown]
# Mari kita cek bahwa dataframe kita sekarang hanya terdiri dari 100 kejahatan.

# %%
df_incidents.shape
# Out:
# (100, 13)

# %% [markdown]
# Sekarang setelah kita sedikit mengurangi datanya, mari kita visualisasikan di mana saja kejahatan ini terjadi di kota San Francisco. Kami akan menggunakan style default dan inisialisasi tingkat zoom ke 12.

# %%
# latitude dan longitude San Francisco
latitude = 37.77
longitude = -122.42

# %%
# membuat peta san fransisco
sanfran_map = folium.Map(
    [latitude, longitude],
    zoom_start=12
)

sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_986d8b82a4e0e2937ec1e863de073c4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_986d8b82a4e0e2937ec1e863de073c4b = L.map(
#                 &quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145633f2af9fa332efc458fd0b969d5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_145633f2af9fa332efc458fd0b969d5f.addTo(map_986d8b82a4e0e2937ec1e863de073c4b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Sekarang mari kita letakkan lokasi kejahatan pada peta. Cara melakukannya di **Folium** adalah dengan membuat *grup fitur* dengan fitur dan gayanya sendiri lalu menambahkannya ke `sanfran_map`.

# %%
# Membuat Grup Fitur bernama incidents
import folium.vector_layers

incidents = folium.map.FeatureGroup()

# Menambahkan data incidents
for lat, long in zip(df_incidents['Y'], df_incidents['X']):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # berarti markernya akan diwarnai bagian dalamnya
            fill_color='blue',      # warna isi
            fill_opacity=0.6        # transparansi 60%
        )
    )

# menambahkan feature group ke dalam peta San Fransisco
incidents.add_to(sanfran_map)

# Menampilkan peta San Fransisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_986d8b82a4e0e2937ec1e863de073c4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_986d8b82a4e0e2937ec1e863de073c4b = L.map(
#                 &quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145633f2af9fa332efc458fd0b969d5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_145633f2af9fa332efc458fd0b969d5f.addTo(map_986d8b82a4e0e2937ec1e863de073c4b);
#
#
#             tile_layer_145633f2af9fa332efc458fd0b969d5f.addTo(map_986d8b82a4e0e2937ec1e863de073c4b);
#
#
#             var feature_group_297e43aa02c5ba46309f88d4697f31dd = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_38e1b8ffd6208ee4d00bdd1696afcd68 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_055381e7dc816f33a386edaf187afb8b = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_e463e1e1e4a67e68d5fd40fe87808dc2 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_8f58e1e1f6b403fbc4e341e456fff57b = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_5f990ca55b05b8929d4d71e7a74b611e = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_57aa1bb9b175409af4c3af6771174ee9 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round

# %% [markdown]
# Kita juga dapat menambahkan beberapa teks pop-up yang akan ditampilkan saat kita mengarahkan kursor ke penanda. Mari kita buat setiap penanda menampilkan kategori kejahatan ketika diarahkan.

# %%
# Membuat Grup Fitur bernama incidents
import folium.vector_layers

incidents = folium.map.FeatureGroup()

# Menambahkan data incidents
for lat, long in zip(df_incidents['Y'], df_incidents['X']):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # berarti markernya akan diwarnai bagian dalamnya
            fill_color='blue',      # warna isi
            fill_opacity=0.6        # transparansi 60%
        )
    )

# menambahkan pop up berisi jenis kejahatan
for lat, long, label in zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category']):
    folium.Marker(
        [lat, long],
        popup=label
    ).add_to(sanfran_map)

# menambahkan feature group ke dalam peta San Fransisco
incidents.add_to(sanfran_map)

# Menampilkan peta San Fransisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_986d8b82a4e0e2937ec1e863de073c4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_986d8b82a4e0e2937ec1e863de073c4b = L.map(
#                 &quot;map_986d8b82a4e0e2937ec1e863de073c4b&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145633f2af9fa332efc458fd0b969d5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_145633f2af9fa332efc458fd0b969d5f.addTo(map_986d8b82a4e0e2937ec1e863de073c4b);
#
#
#             tile_layer_145633f2af9fa332efc458fd0b969d5f.addTo(map_986d8b82a4e0e2937ec1e863de073c4b);
#
#
#             var feature_group_297e43aa02c5ba46309f88d4697f31dd = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_38e1b8ffd6208ee4d00bdd1696afcd68 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_055381e7dc816f33a386edaf187afb8b = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_e463e1e1e4a67e68d5fd40fe87808dc2 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_8f58e1e1f6b403fbc4e341e456fff57b = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_5f990ca55b05b8929d4d71e7a74b611e = L.circleMarker(
#                 [37.7650501214668, -122.419671780296],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_297e43aa02c5ba46309f88d4697f31dd);
#
#
#             var circle_marker_57aa1bb9b175409af4c3af6771174ee9 = L.circleMarker(
#                 [37.788018555829, -122.426077177375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round

# %% [markdown]
# Sekarang kita dapat mengetahui kategori kejahatan yang terjadi di setiap penanda.
#
# Jika kita merasa peta terlalu padat dengan semua penanda ini, ada dua solusi untuk masalah ini. Solusi yang lebih sederhana adalah menghapus penanda lokasi ini dan hanya menambahkan teks ke penanda lingkaran itu sendiri sebagai berikut:

# %%
# membuat peta san fransisco
sanfran_map = folium.Map(
    [latitude, longitude],
    zoom_start=12
)

# Membuat Grup Fitur bernama incidents
import folium.vector_layers

incidents = folium.map.FeatureGroup()

# Menambahkan data incidents
for lat, long, label in zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category']):
    incidents.add_child(
        folium.vector_layers.CircleMarker(
            [lat, long],
            radius=5,               # ukuran lingkaran
            color='yellow',         # warna lingkaran
            fill=True,              # berarti markernya akan diwarnai bagian dalamnya
            fill_color='blue',      # warna isi
            fill_opacity=0.6,        # transparansi 60%
            popup=label
        )
    )

# menambahkan feature group ke dalam peta San Fransisco
incidents.add_to(sanfran_map)

# Menampilkan peta San Fransisco
sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7d5e0e519f3349af099ba65847374d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7d5e0e519f3349af099ba65847374d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7d5e0e519f3349af099ba65847374d3 = L.map(
#                 &quot;map_f7d5e0e519f3349af099ba65847374d3&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a7631e23197f37c573fe1af2e6af4a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a7631e23197f37c573fe1af2e6af4a6.addTo(map_f7d5e0e519f3349af099ba65847374d3);
#
#
#             var feature_group_ea72b2a17c9b8e45a16c4b2feced6da2 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_bef4bad396ccb16d57bce4ebd65aa664 = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea72b2a17c9b8e45a16c4b2feced6da2);
#
#
#         var popup_4c65858b8a830b4ffcf0be26e3aeefa5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57d61a13041ae9108862f6c609226cfd = $(`&lt;div id=&quot;html_57d61a13041ae9108862f6c609226cfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_4c65858b8a830b4ffcf0be26e3aeefa5.setContent(html_57d61a13041ae9108862f6c609226cfd);
#
#
#
#         circle_marker_bef4bad396ccb16d57bce4ebd65aa664.bindPopup(popup_4c65858b8a830b4ffcf0be26e3aeefa5)
#         ;
#
#
#
#
#             var circle_marker_c28fcece6ae69f647493daa00607be6b = L.circleMarker(
#                 [37.775420706711, -122.403404791479],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea72b2a17c9b8e45a16c4b2feced6da2);
#
#
#         var popup_e54056de77c53638a3f0867c5b893143 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6aea0a823e212ad85926772d8605682a = $(`&lt;div id=&quot;html_6aea0a823e212ad85926772d8605682a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_e54056de77c53638a3f0867c5b893143.setContent(html_6aea0a823e212ad85926772d8605682a);
#
#
#
#         circle_marker_c28fcece6ae69f647493daa00607be6b.bindPopup(popup_e54056de77c53638a3f0867c5b893143)
#         ;
#
#
#
#
#             var circle_marker_ed44b17df002e8162f80a99ca5e953a7 = L.circleMarker(
#                 [37.7299809672996, -122.388856204292],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_ea72b2a17c9b8e45a16c4b2feced6da2);
#
#
#         var popup_ca854e22b0c6ca7e6cb8b0a6dd7792c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3859b4f2af2c2c1757dd47430c7cfb4 = $(`&lt;div id=&quot;html_e3859b4f2af2c2c1757dd47430c7cfb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_ca854e22b0c6ca7e6cb8b0a6dd7792c7.setContent(html_e3859b4f2af2c2c1757dd47430c7cfb4);
#
#
#
#         circle_marker_ed44b17df002e8162f80a99ca5e953a7.bindPopup(popup_ca854e22b0c6ca7e6cb8b0a6dd7792c7)
#         ;
#
#
#
#
#             var circle_marker_8e79cac89b1813c8a4604b1b40b7a129 = L.circleMarker(
#                 [37.7857883766888, -122.412970537591],
#                 {&quot;bubblin

# %% [markdown]
# Solusi yang tepat lainnya adalah mengelompokkan penanda ke dalam klaster yang berbeda. Setiap klaster kemudian direpresentasikan oleh jumlah kejahatan di setiap lingkungan. Klaster ini dapat dianggap sebagai kantong-kantong San Francisco yang kemudian dapat kita analisis secara terpisah.
#
# Untuk menerapkannya, kita memulai dengan menginisialisasi sebuah objek `MarkerCluster` dan menambahkan semua titik data dalam dataframe ke objek ini.

# %%
from folium import plugins

# membuat peta san fransisco
sanfran_map = folium.Map(
    [latitude, longitude],
    zoom_start=12
)

# menginisiasi Marker Cluster
incidents = plugins.MarkerCluster().add_to(sanfran_map)

# menambahkan marker ke dalam Marker Cluster
for lat, long, label in zip(df_incidents['Y'], df_incidents['X'], df_incidents['Category']):
    folium.Marker(
        [lat, long],
        popup=label,
        icon=None
    ).add_to(incidents)

sanfran_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38c6a844dfdfdef495edcf168225240e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38c6a844dfdfdef495edcf168225240e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38c6a844dfdfdef495edcf168225240e = L.map(
#                 &quot;map_38c6a844dfdfdef495edcf168225240e&quot;,
#                 {
#                     center: [37.77, -122.42],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cfb33120f7ab85902d7e5f02df976f76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cfb33120f7ab85902d7e5f02df976f76.addTo(map_38c6a844dfdfdef495edcf168225240e);
#
#
#             var marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_8d793280a297201c7dc2368e132be75a = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777);
#
#
#         var popup_9c6852d4ef23bf54a406a73b422791d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ac10f7e7b0e76f19a43b77c19037541 = $(`&lt;div id=&quot;html_8ac10f7e7b0e76f19a43b77c19037541&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_9c6852d4ef23bf54a406a73b422791d0.setContent(html_8ac10f7e7b0e76f19a43b77c19037541);
#
#
#
#         marker_8d793280a297201c7dc2368e132be75a.bindPopup(popup_9c6852d4ef23bf54a406a73b422791d0)
#         ;
#
#
#
#
#             var marker_f808db07e3852641c7d9ce7df015cab4 = L.marker(
#                 [37.775420706711, -122.403404791479],
#                 {}
#             ).addTo(marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777);
#
#
#         var popup_ef68bd3eabc7bb921226fd08129730d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1acf0170583b4f2db934ff4db633dc96 = $(`&lt;div id=&quot;html_1acf0170583b4f2db934ff4db633dc96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WEAPON LAWS&lt;/div&gt;`)[0];
#                 popup_ef68bd3eabc7bb921226fd08129730d2.setContent(html_1acf0170583b4f2db934ff4db633dc96);
#
#
#
#         marker_f808db07e3852641c7d9ce7df015cab4.bindPopup(popup_ef68bd3eabc7bb921226fd08129730d2)
#         ;
#
#
#
#
#             var marker_b3ed15ec226b09bb3fc095fd2039901b = L.marker(
#                 [37.7299809672996, -122.388856204292],
#                 {}
#             ).addTo(marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777);
#
#
#         var popup_16c0f4dc1eaeb60947fedafc7df0c31d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_264e81d0e3436c63d0ca0bd4a462a742 = $(`&lt;div id=&quot;html_264e81d0e3436c63d0ca0bd4a462a742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;WARRANTS&lt;/div&gt;`)[0];
#                 popup_16c0f4dc1eaeb60947fedafc7df0c31d.setContent(html_264e81d0e3436c63d0ca0bd4a462a742);
#
#
#
#         marker_b3ed15ec226b09bb3fc095fd2039901b.bindPopup(popup_16c0f4dc1eaeb60947fedafc7df0c31d)
#         ;
#
#
#
#
#             var marker_117d76bdaad2179b0fcf5048e3167018 = L.marker(
#                 [37.7857883766888, -122.412970537591],
#                 {}
#             ).addTo(marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777);
#
#
#         var popup_ca2612277ff2ab7c9733e8dba56d1f30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce4ca83f41fea3775930bea978da4b7b = $(`&lt;div id=&quot;html_ce4ca83f41fea3775930bea978da4b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NON-CRIMINAL&lt;/div&gt;`)[0];
#                 popup_ca2612277ff2ab7c9733e8dba56d1f30.setContent(html_ce4ca83f41fea3775930bea978da4b7b);
#
#
#
#         marker_117d76bdaad2179b0fcf5048e3167018.bindPopup(popup_ca2612277ff2ab7c9733e8dba56d1f30)
#         ;
#
#
#
#
#             var marker_52c032a862e437dca9b6f9349a80cd12 = L.marker(
#                 [37.7650501214668, -122.419671780296],
#                 {}
#             ).addTo(marker_cluster_ff98275c2e140f2ea5b0dd1d6a43a777);
#
#
#         var popup_6a019e1510e1e63edec49f086224f2e1 = L.popup({&quot;maxWidth&quot;: &

# %% [markdown]
# Perhatikan bagaimana saat Anda memperkecil tampilan peta sepenuhnya, semua penanda digabungkan ke dalam satu klaster, *klaster global*, dengan 100 penanda atau kejahatan, yang merupakan total jumlah kejahatan dalam dataframe kami. Begitu Anda mulai memperbesar, *klaster global* akan mulai terpecah menjadi klaster yang lebih kecil. Memperbesar hingga sepenuhnya akan menghasilkan penanda individu.

# %% [markdown]
# ## **4. Choropleth Maps**
#
#
# Peta `Choropleth` adalah peta tematis di mana area-area diarsir atau dipola secara proporsional dengan pengukuran variabel statistik yang ditampilkan pada peta, seperti kepadatan penduduk atau pendapatan per kapita. Peta `choropleth` menyediakan cara yang mudah untuk memvisualisasikan bagaimana pengukuran bervariasi di seluruh area geografis, atau menunjukkan tingkat variabilitas dalam suatu wilayah. Di bawah ini adalah peta `Choropleth` dari Amerika Serikat yang menggambarkan populasi per mil persegi per negara bagian.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%205/images/2000_census_population_density_map_by_state.png" width="600">

# %% [markdown]
# Sekarang kita akan membuat `Choropleth` yang menggambarkan perpindahan penduduk di kota Jakarta.

# %% [markdown]
# Pertama kita baca terlebih dahulu file `pendatang_DKI_Maret_2020.csv` ke dalam *pandas* dataframe.

# %%
df = pd.read_csv('../../csv/pendatang_DKI_Maret_2020.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df = pd.read_csv('../../csv/pendatang_DKI_Maret_2020.csv')
#       2 df.head()
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../csv/pendatang_DKI_Maret_2020.csv'

# %% [markdown]
# Selanjutnya kita perlu menampilkan jumlah pendatang berdasarkan kelurahan.

# %%
df = df.groupby('kelurahan', as_index=False)[['jumlah']].sum()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df = df.groupby('kelurahan', as_index=False)[['jumlah']].sum()
#       2 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Dalam rangka membuat peta `Choropleth`, kita membutuhkan file GeoJSON yang mendefinisikan area/batas dari suatu kota, provinsi, atau negara yang menarik perhatian kita. Dalam kasus ini, karena kita berusaha membuat peta jakarta, kita membutuhkan GeoJSON yang membatasi seluruh kelurahan di kota Jakarta. Demi kenyamanan, kita sudah menyediakan file `jakarta_by_kelurahan_geo.geojson`. Mari kita namai jakarta_geojson

# %%
jakarta_geojson = r'jakarta_by_kelurahan_geo.geojson'

# %% [markdown]
# Untuk mengetahui apa yang terkandung di dalamnya kita bisa menggunakan metode `read_json`.

# %%
pd.read_json('jakarta_by_kelurahan_geo.geojson').loc[0, 'features']['properties']['name']
# Out:
# 'ANGKE'

# %% [markdown]
# Dan sekarang untuk membuat peta `Choropleth`, kita akan menggunakan metode *choropleth* dengan parameter utama sebagai berikut:
#
# 1. `geo_data`, yaitu file GeoJSON.
# 2. `data`, yaitu dataframe yang berisi data.
# 3. `columns`, yang mewakili kolom-kolom dalam dataframe yang akan digunakan untuk membuat peta `Choropleth`.
# 4. `key_on`, yaitu kunci atau variabel pada file GeoJSON yang berisi nama variabel yang diinginkan. Untuk menentukannya, kita perlu membuka file GeoJSON menggunakan editor teks apa pun dan mencatat nama kunci atau variabel yang berisi nama kelurahan, karena kelurahan adalah variabel yang kita minati. Dalam hal ini, **name** adalah kunci dalam file GeoJSON yang berisi nama kelurahan. Perhatikan bahwa kunci ini case sensitive, jadi kita harus meneruskannya persis seperti yang ada di file GeoJSON.

# %%
df.head()
# Out:
#      kelurahan  jumlah
# 0        ANCOL    17.0
# 1        ANGKE    22.0
# 2  BALEKAMBANG    30.0
# 3  BALI MESTER     4.0
# 4   BAMBU APUS    26.0

# %%
# menampilkan peta jakarta yang terpusat di monas
lat_monas = -6.175392
long_monas = 106.827153

jakarta_map=folium.Map(
    [lat_monas, long_monas],                 # latitude, longitude
    zoom_start=11                            # ukuran zoom awal
)

# membuat choropleth
chor_kelurahan = folium.Choropleth(
    geo_data=jakarta_geojson,               # file geojson
    data=df,                                # dataframe pandas
    columns=['kelurahan', 'jumlah'],        # kolom key dan kolom value yang akan ditampilkan dari dataframe
    key_on='feature.properties.name'       # indexing nama kelurahan dari file geojson
)

# menambahkan choropleth ke kota jakarta
chor_kelurahan.add_to(jakarta_map)

jakarta_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 lat_monas = -6.175392
#       3 long_monas = 106.827153
# ----> 5 jakarta_map=folium.Map(
#       6     [lat_monas, long_monas],                 # latitude, longitude
#       7     zoom_start=11                            # ukuran zoom awal
#       8 )
#      10 # membuat choropleth
#      11 chor_kelurahan = folium.Choropleth(
#      12     geo_data=jakarta_geojson,               # file geojson
#      13     data=df,                                # dataframe pandas
#      14     columns=['kelurahan', 'jumlah'],        # kolom key dan kolom value yang akan ditampilkan dari dataframe
#      15     key_on='feature.properties.name'       # indexing nama kelurahan dari file geojson
#      16 )
#
# NameError: name 'folium' is not defined

# %% [markdown]
# Sesuai dengan legenda pada peta `Choroplet`, semakin gelap warna suatu kelurahan dan semakin mendekati warna biru tua, semakin tinggi jumlah perpindahan penduduknya. Oleh karena itu, perpindahan penduduk terjadi di sekitar perbatasan kota Jakarta.
#
# Perhatikan bahwa masih terdapat data yang tidak muncul di dalam peta, hal ini bisa terjadi karena nama kelurahan pada file geojson dan pada dataframe berbeda. Sehingga kita perlu sesuaikan nama-namanya terlebih dahulu.

# %%
df[df['kelurahan'].str.contains('CEGER')]
# Out:
#    kelurahan  jumlah
# 16     CEGER    13.0

# %%
df['kelurahan'] = df['kelurahan'].str.replace('WIJAYA KUSUMA', 'WIJAYA KESUMA')
df['kelurahan'] = df['kelurahan'].str.replace('JATIPULO', 'JATI PULO')
df['kelurahan'] = df['kelurahan'].str.replace('SETIA BUDI', 'SETIABUDI')
df['kelurahan'] = df['kelurahan'].str.replace('PALMERIAM', 'PAL MERIAM')
df['kelurahan'] = df['kelurahan'].str.replace('PULO GADUNG', 'PULOGADUNG')
df['kelurahan'] = df['kelurahan'].str.replace('JATI PADANG', 'JATIPADANG')
df['kelurahan'] = df['kelurahan'].str.replace('PONDOK RANGGON', 'PONDOK RANGON')
df['kelurahan'] = df['kelurahan'].str.replace('TENGAH', 'KAMPUNG TENGAH')
df['kelurahan'] = df['kelurahan'].str.replace('KRAMATJATI', 'KRAMAT JATI')
df['kelurahan'] = df['kelurahan'].str.replace('PINANGRANTI', 'PINANG RANTI')
df['kelurahan'] = df['kelurahan'].str.replace('BALEKAMBANG', 'BALE KAMBANG')
df['kelurahan'] = df['kelurahan'].str.replace('HALIM PERDANA KUSUMAH', 'HALIM PERDANA KUSUMA')

# %%
df.loc[267, 'kelurahan'] = 'TMII'
df.loc[267, 'jumlah'] = 0

# %%
df.tail()
# Out:
#            kelurahan  jumlah
# 263  UTAN KAYU UTARA    25.0
# 264     UTAN PANJANG    13.0
# 265          WARAKAS    22.0
# 266    WIJAYA KESUMA    31.0
# 267             TMII     0.0

# %% [markdown]
# Setelah kita perbaiki datanya, kita akan coba tampilkan kembali sambil mengubah warna dan legenda dari peta tersebut.

# %%
df['jumlah'].quantile([0, 0.25, 0.5, 0.75, 1])
# Out:
# 0.00      0.0
# 0.25     13.0
# 0.50     24.0
# 0.75     36.0
# 1.00    145.0
# Name: jumlah, dtype: float64

# %%
# menampilkan peta jakarta yang terpusat di monas
lat_monas = -6.175392
long_monas = 106.827153

jakarta_map=folium.Map(
    [lat_monas, long_monas],                 # latitude, longitude
    zoom_start=11                            # ukuran zoom awal
)

# membuat choropleth
chor_kelurahan = folium.Choropleth(
    geo_data=jakarta_geojson,               # file geojson
    data=df,                                # dataframe pandas
    columns=['kelurahan', 'jumlah'],        # kolom key dan kolom value yang akan ditampilkan dari dataframe
    key_on='feature.properties.name',       # indexing nama kelurahan dari file geojson
    fill_color='YlOrRd',                    # mengubah warna
    legend_name='Jumlah Pendatang',         # nama legenda
    fill_opacity=0.5,                       # transparansi
    bins=df['jumlah'].quantile([0, 0.25, 0.5, 0.75, 1])            # mengatur rentang warna
)

# menambahkan choropleth ke kota jakarta
chor_kelurahan.add_to(jakarta_map)

jakarta_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 12
#       5 jakarta_map=folium.Map(
#       6     [lat_monas, long_monas],                 # latitude, longitude
#       7     zoom_start=11                            # ukuran zoom awal
#       8 )
#      10 # membuat choropleth
#      11 chor_kelurahan = folium.Choropleth(
# ---> 12     geo_data=jakarta_geojson,               # file geojson
#      13     data=df,                                # dataframe pandas
#      14     columns=['kelurahan', 'jumlah'],        # kolom key dan kolom value yang akan ditampilkan dari dataframe
#      15     key_on='feature.properties.name',       # indexing nama kelurahan dari file geojson
#      16     fill_color='YlOrRd',                    # mengubah warna
#      17     legend_name='Jumlah Pendatang',         # nama legenda
#      18     fill_opacity=0.5,                       # transparansi
#      19     bins=df['jumlah'].quantile([0, 0.25, 0.5, 0.75, 1])            # mengatur rentang warna
#      20 )
#      22 # menambahkan choropleth ke kota jakarta
#      23 chor_kelurahan.add_to(jakarta_map)
#
# NameError: name 'jakarta_geojson' is not defined
