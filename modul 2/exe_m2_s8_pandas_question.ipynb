# %%
# 

import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# 1. Tampilkan nilai yang paling sering muncul pada kolom 'origin'

# %%
df['origin'].value_counts().index[0]
# Out:
# 'usa'

# %% [markdown]
# 2. Tampilkan rata-rata horsepower

# %%
df['horsepower'].mean()
# Out:
# 104.46938775510205

# %% [markdown]
# 3. Tampilkan rata-rata acceleration tiap cylinder

# %%
df.groupby('cylinders')[['acceleration']].mean()
# Out:
#            acceleration
# cylinders
# 3             13.250000
# 4             16.601471
# 5             18.633333
# 6             16.263095
# 8             12.955340

# %% [markdown]
# 4. Tampilkan rata-rata acceleration tiap cylinder dan origin

# %%
df.groupby(['cylinders','origin'])[['acceleration']].mean()
# Out:
#                   acceleration
# cylinders origin
# 3         japan      13.250000
# 4         europe     16.722222
#           japan      16.569565
#           usa        16.526389
# 5         europe     18.633333
# 6         europe     16.425000
#           japan      13.550000
#           usa        16.474324
# 8         usa        12.955340

# %% [markdown]
# 5. Tampilkan rata-rata acceleration tiap cylinder dan origin, kemudian urutkan hasilnya dari acceleration paling tinggi.

# %%
df.groupby(['cylinders','origin'])[['acceleration']].mean().sort_values(['acceleration'],ascending=False)
# Out:
#                   acceleration
# cylinders origin
# 5         europe     18.633333
# 4         europe     16.722222
#           japan      16.569565
#           usa        16.526389
# 6         usa        16.474324
#           europe     16.425000
#           japan      13.550000
# 3         japan      13.250000
# 8         usa        12.955340

# %% [markdown]
# 6. Tampilkan jumlah mobil tiap cylinder

# %%
df['cylinders'].value_counts()
# Out:
# cylinders
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: count, dtype: int64

# %% [markdown]
# 7. Tampilkan mobil dari japan dengan nilai mpg paling tinggi

# %%
df[df['origin'] == 'japan'].sort_values(by='mpg', ascending=False).head(1)[['name','mpg']]
# Out:
#           name   mpg
# 322  mazda glc  46.6

# %% [markdown]
# 8. Displacement adalah jumlah volume total dari seluruh cylinder. Buat kolom baru bernama 'volume_per_cylinder'.

# %%
df.rename(columns={'displacement':'volume_per_cylinder'}, inplace=True)
df
# Out:
#       mpg  cylinders  volume_per_cylinder  horsepower  weight  acceleration  \
# 0    18.0          8                307.0       130.0    3504          12.0
# 1    15.0          8                350.0       165.0    3693          11.5
# 2    18.0          8                318.0       150.0    3436          11.0
# 3    16.0          8                304.0       150.0    3433          12.0
# 4    17.0          8                302.0       140.0    3449          10.5
# ..    ...        ...                  ...         ...     ...           ...
# 393  27.0          4                140.0        86.0    2790          15.6
# 394  44.0          4                 97.0        52.0    2130          24.6
# 395  32.0          4                135.0        84.0    2295          11.6
# 396  28.0          4                120.0        79.0    2625          18.6
# 397  31.0          4                119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# 9. Tampilkan jumlah mobil keluaran tahun 1975

# %%
len(df[df['model_year'] == 75])
# Out:
# 30

# %% [markdown]
# 10. Buat kolom baru bernama 'origin_brand' berisi nama origin dan brand-nya.
#
#     Contoh:
#     - usa chevrolet
#     - usa buick
#     - europe vw

# %%
df['origin_brand'] = df['origin'] + ' ' + df['name']
df
# Out:
#       mpg  cylinders  volume_per_cylinder  horsepower  weight  acceleration  \
# 0    18.0          8                307.0       130.0    3504          12.0
# 1    15.0          8                350.0       165.0    3693          11.5
# 2    18.0          8                318.0       150.0    3436          11.0
# 3    16.0          8                304.0       150.0    3433          12.0
# 4    17.0          8                302.0       140.0    3449          10.5
# ..    ...        ...                  ...         ...     ...           ...
# 393  27.0          4                140.0        86.0    2790          15.6
# 394  44.0          4                 97.0        52.0    2130          24.6
# 395  32.0          4                135.0        84.0    2295          11.6
# 396  28.0          4                120.0        79.0    2625          18.6
# 397  31.0          4                119.0        82.0    2720          19.4
#
#      model_year  origin                       name  \
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
#                       origin_brand
# 0    usa chevrolet chevelle malibu
# 1            usa buick skylark 320
# 2           usa plymouth satellite
# 3                usa amc rebel sst
# 4                  usa ford torino
# ..                             ...
# 393            usa ford mustang gl
# 394               europe vw pickup
# 395              usa dodge rampage
# 396                usa ford ranger
# 397                 usa chevy s-10
#
# [398 rows x 10 columns]

# %%
# Out:
# Requirement already satisfied: regex in c:\users\fiki\anaconda3\lib\site-packages (2023.10.3)
