# %% [markdown]
# # 🦾 Pandas Practice Session

# %% [markdown]
# ## 💡 What is Pandas ?
#
# ![pandas](https://i.redd.it/c6h7rok9c2v31.jpg)
#
# **Pandas** is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Create Dataframe 🔳

# %% [markdown]
# ### Question 1
#
# Membuat dataframe dengan 3 kolom yaitu x,y dan z. memiliki data berurutan dari setiap kolom angka 1 sampai 15

# %% [markdown]
# **Answer** ⬇️

# %%
data = {
    'x': list(range(1, 6)),
    'y': list(range(6, 11)),
    'z': list(range(11, 16))
}
df = pd.DataFrame(data)
df
# Out:
#    x   y   z
# 0  1   6  11
# 1  2   7  12
# 2  3   8  13
# 3  4   9  14
# 4  5  10  15

# %% [markdown]
# ### Question 2
# Menambahkan kolom 'v' yang memiliki nilai data kebawah yaitu 16-20

# %%
df['v'] = [x for x in range(16,21)]
df
# Out:
#    x   y   z   v     f
# 0  1   6  11  16   Low
# 1  2   7  12  17   Low
# 2  3   8  13  18   Low
# 3  4   9  14  19  High
# 4  5  10  15  20  High

# %% [markdown]
# **Answer** ⬇️

# %% [markdown]
# ## Selection & indexing 🤚

# %% [markdown]
# ### Question 1
# Dapatkan kolom dari 'x' dan 'y'

# %% [markdown]
# **Answer** ⬇️

# %%
df[['x', 'y']]
# Out:
#    x   y
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %% [markdown]
# ### Question 2
# Dapatkan data dengan index 2 dan hanya kolom 'x' dan 'y' saja

# %%
df[['x', 'y']].loc[[2]]
# Out:
#    x  y
# 2  3  8

# %% [markdown]
# **Answer** ⬇️

# %% [markdown]
# ### Question 3
# Seleksi data yang memiliki nilai lebih dari 13

# %% [markdown]
# **Answer** ⬇️

# %%
df[df>13]
# Out:
#     x   y     z   v
# 0 NaN NaN   NaN  16
# 1 NaN NaN   NaN  17
# 2 NaN NaN   NaN  18
# 3 NaN NaN  14.0  19
# 4 NaN NaN  15.0  20

# %% [markdown]
# ## Data Manipulation 🧙

# %% [markdown]
# ### Question 1
# Buat kolom baru nama 'f' yaitu dengan menggunakan nilai dari kolom 'v' apakah lebih besar dari 18 atau tidak

# %% [markdown]
# **Answer** ⬇️

# %%
lst = []
for i in df['v']:
    if i > 18:
        temp = 'High'
    else:
        temp = 'Low'
    lst.append(temp)
df['f'] = lst
df
# Out:
#    x   y   z   v     f
# 0  1   6  11  16   Low
# 1  2   7  12  17   Low
# 2  3   8  13  18   Low
# 3  4   9  14  19  High
# 4  5  10  15  20  High

# %% [markdown]
# ### Question 2
# Hapus kolom 'y'

# %% [markdown]
# **Answer** ⬇️

# %%
df.drop('y', axix='columns', inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.drop('y', axix='columns', inplace=True)
#       2 df
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'axix'

# %% [markdown]
# ### Question 3
# Urutkan data berdasarkan kolom 'v' secara descending

# %%
# Out:
#    x   z   v     f
# 4  5  15  20  High
# 3  4  14  19  High
# 2  3  13  18   Low
# 1  2  12  17   Low
# 0  1  11  16   Low

# %% [markdown]
# **Answer** ⬇️

# %%
df.sort_values('v',ascending=False)
df
# Out:
#    x   y   z   v     f
# 0  1   6  11  16   Low
# 1  2   7  12  17   Low
# 2  3   8  13  18   Low
# 3  4   9  14  19  High
# 4  5  10  15  20  High

# %% [markdown]
# ## Data Read 👁️

# %% [markdown]
# ### Question 1
# Read csv file

# %%
# Out:
#     Username   Identifier First name Last name
# 0   booker12         9012     Rachel    Booker
# 1     grey07         2070      Laura      Grey
# 2  johnson81         4081      Craig   Johnson
# 3  jenkins46         9346       Mary   Jenkins
# 4    smith79         5079      Jamie     Smith

# %% [markdown]
# **Answer** ⬇️

# %%
pd.read_csv('../../csv/username.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.read_csv('../../csv/username.csv')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Question 2
# read excel file 'customer.xls'

# %%
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %% [markdown]
# **Answer** ⬇️

# %%
pd.read_excel('data/username.xls')

# %% [markdown]
# ### Question 3
# read excel file 'customer.xls' sheet 2

# %%
pd.read_csv('data/customer.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 pd.read_csv('data/customer.csv')
#
# File c:\Users\Fiki\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
# ...

# %% [markdown]
# **Answer** ⬇️
